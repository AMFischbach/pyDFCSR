# %%
from csr3d import CSR3D

# %%
# %matplotlib widget
# %load_ext line_profiler
csr_3d = CSR3D(input_file= 'input/dipole_config.yaml')


#csr_3d.run()
#csr_3d.save_data(directory="/Users/amf16/Desktop/SULI 2024/Simulation Output", filename="dipole super new code.h5")

#%lprun -f CSR3D.compute_CSR_on_mesh csr_3d.run()
# %lprun -f CSR3D.compute_CSR_at_point csr_3d.run()
#%lprun -f CSR3D.get_CSR_integrand csr_3d.run()


#csr_3d.save_data(directory="/Users/amf16/Desktop/SULI 2024/Simulation Output", filename = "new code dipole.h5")
#csr_3d.run()
#csr_3d.demonstrate_coordinate_transfer()

#csr_3d.save_data(directory="/Users/amf16/Desktop/SULI 2024/Simulation Output", filename="new_code_data.h5")

#create_beam_gif(csr_3d.step_snapshots)

#%lprun -f Step_Snapshot.populate_2D_histograms csr_3d.run()
# Out:
# done with init
# Timer unit: 1e-09 s
#
# Total time: 5.3768 s
# File: /Users/amf16/pyDFCSR/fast_pyDFCSR_2D/csr3d.py
# Function: get_CSR_integrand at line 301
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    301                                               def get_CSR_integrand(self, s, x, area, step_index):
#    302                                                   """
#    303                                                   Helper function to compute_CSR_at_point, finds the integrand contribution (W1 + W2 + W3) of the inputed integration area
#    304                                                   to the specific point
#    305                                                   """
#    306                                                   # Define t
#    307      1200    1255000.0   1045.8      0.0          t = self.beam.position
#    308
#    309                                                   # Flatten the meshgrid
# ...
