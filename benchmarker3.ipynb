# %%
import h5py
import matplotlib.pyplot as plt

from pyDFCSR3D_post_processor import load_new_data, load_old_data, plot_statistic

# %%
new_CSR_statistics = load_new_data("/Users/amf16/Desktop/SULI 2024/Simulation Output/dipole super new code.h5")
old_CSR_statistics = load_old_data("/Users/amf16/Desktop/SULI 2024/Simulation Output/dipole-2024-07-30T12_23_19-07_00-statistics.h5")

# %%
# Plots some statistics
plt.figure()
plot_statistic(new_CSR_statistics["sigma_z"], new_figure=False, label="sigma_z new CSR wake", color="red")
plot_statistic(old_CSR_statistics["sigma_z"], new_figure=False, label="sigma_z old CSR wake", color="blue")
plt.title("sigma_z with and without CSR wake applied")
plt.xlabel("step number")
plt.legend()
plt.show()

plt.figure()
plot_statistic(new_CSR_statistics["twiss"]["emit_x"], new_figure=False, label="emit_x new CSR wake", color="red")
plot_statistic(old_CSR_statistics["twiss"]["emit_x"], new_figure=False, label="emit_x old CSR wake", color="blue")
plt.title("emit_x with and without CSR wake applied")
plt.xlabel("step number")
plt.legend()
plt.show()
